# %% [markdown]
# # My Question 6-2

# %%
# question 1

# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %%
tables = pd.read_html('http://www.wdcdance.com/index.php/competitive-dance/calendar-all-events')
len(tables)
# Out:
# 93

# %%
ProAm = pd.DataFrame(tables[0])
ProAm
# Out:
#             0   1                                                  2
# 0  19.01.2019 NaN  2019 Crystal Ball - WDC European Cup & WDC AL ...

# %%
ProAm_all = pd.DataFrame(tables)

# %%
ProAm_all
# Out:
#                                                     0
# 0               0   1                             ...
# 1               0   1                             ...
# 2               0   1                             ...
# 3               0   1                             ...
# 4               0   1                             ...
# 5               0   1                             ...
# 6               0   1                             ...
# 7               0   1                             ...
# 8               0   1                             ...
# 9               0   1                             ...
# 10              0   1                             ...
# 11              0   1                             ...
# 12              0   1                             ...
# 13              0   1                             ...
# 14              0   1                             ...
# 15              0   1                             ...
# ...

# %%
tables
# Out:
# [            0   1                                                  2
#  0  19.01.2019 NaN  2019 Crystal Ball - WDC European Cup & WDC AL ...,
#              0   1                                                  2
#  0  19.01.2019 NaN  3rd Aquilia-NTU DanceSport Championship 2019  ...,
#              0   1                                                  2
#  0  20.01.2019 NaN  Palm Beach Classic  Division: Ballroom & Latin...,
#              0   1                                                  2
#  0  27.01.2019 NaN  Majesty Dance Sport Festival  Division: Ballro...,
#              0   1                                                  2
#  0  31.01.2019 NaN  Maryland Dancesport  Division: Ballroom & Lati...,
#              0   1                                                  2
#  0  01.02.2019 NaN  Platinum DanceSport Classic  Division: Ballroo...,
#              0   1                                                  2
# ...

# %%
import requests

# %%
url = 'https://api.nal.usda.gov/ndb/V2/reports?ndbno=01009&ndbno=01009&ndbno=45202763&ndbno=35193&type=b&format=json&api_key=DEMO_KEY'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
import json

# %%
data = resp.json()

# %%
data
# Out:
# {'foods': [{'food': {'sr': '1',
#     'type': 'b',
#     'desc': {'ndbno': '01009',
#      'name': "Cheese, cheddar (Includes foods for USDA's Food Distribution Program)",
#      'ds': 'Standard Reference',
#      'manu': '',
#      'ru': 'g'},
#     'nutrients': [{'nutrient_id': '255',
#       'name': 'Water',
#       'derivation': 'NONE',
#       'group': 'Proximates',
#       'unit': 'g',
#       'value': '36.75',
#       'measures': [{'label': 'cup, diced',
#         'eqv': 132.0,
#         'eunit': 'g',
#         'qty': 1.0,
#         'value': '48.51'},
#        {'label': 'cup, melted',
#         'eqv': 244.0,
#         'eunit': 'g',
#         'qty': 1.0,
#         'value': '89.67'},
#        {'label': 'cup, shredded',
#         'eqv': 113.0,
#         'eunit': 'g',
#         'qty': 1.0,
#         'value': '41.53'},
#        {'label': 'oz',
#         'eqv': 28.35,
#         'eunit': 'g',
#         'qty': 1.0,
#         'value': '10.42'},
#        {'label': 'cubic inch',
# ...

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-80a4aab09c73> in <module>()
# ----> 1 data[0]
#
# KeyError: 0

# %%
USDA = pd.DataFrame(data)

# %%
USDA
# Out:
#                                                foods  count  notfound  api
# 0  {'food': {'sr': '1', 'type': 'b', 'desc': {'nd...      4         1  2.0
# 1  {'food': {'sr': '1', 'type': 'b', 'desc': {'nd...      4         1  2.0
# 2            {'error': 'No data for ndbno 45202763'}      4         1  2.0
# 3  {'food': {'sr': '1', 'type': 'b', 'desc': {'nd...      4         1  2.0

# %% [markdown]
# # others

# %%
import urllib.request, json
with urllib.request.urlopen("http://www.wdcdance.com/index.php/competitive-dance/calendar-all-events") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-e03ba75426ab> in <module>()
#       1 import urllib.request, json
#       2 with urllib.request.urlopen("http://www.wdcdance.com/index.php/competitive-dance/calendar-all-events") as url:
# ----> 3     data = json.loads(url.read().decode())
#       4     print(data)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...
